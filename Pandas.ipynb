# %%
import pandas as pd

# %%
#Dataframe
pd.DataFrame({'Yes': [50, 21], 'No': [131, 2]})
# Out:
#    Yes   No
# 0   50  131
# 1   21    2
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['Yes'].plot(kind='hist', bins=20, title='Yes')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['No'].plot(kind='hist', bins=20, title='No')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_2.plot(kind='scatter', x='Yes', y='No', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# ...

# %%
#series
print(pd.Series([1, 2, 3, 4, 5]))
pd.Series([30, 35, 40], index=['2015 Sales', '2016 Sales', '2017 Sales'], name='Product A')
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64
# 2015 Sales    30
# 2016 Sales    35
# 2017 Sales    40
# Name: Product A, dtype: int64

# %%
input = pd.read_csv("lung_cancer_examples.csv")
input
# Out:
#            Name      Surname  Age  Smokes  AreaQ  Alkhol  Result
# 0          John         Wick   35       3      5       4       1
# 1          John  Constantine   27      20      2       5       1
# 2        Camela     Anderson   30       0      5       2       0
# 3          Alex       Telles   28       0      8       1       0
# 4         Diego     Maradona   68       4      5       6       1
# 5     Cristiano      Ronaldo   34       0     10       0       0
# 6        Mihail          Tal   58      15     10       0       0
# 7         Kathy        Bates   22      12      5       2       0
# 8        Nicole       Kidman   45       2      6       0       0
# 9           Ray      Milland   52      18      4       5       1
# 10      Fredric        March   33       4      8       0       0
# 11          Yul      Brynner   18      10      6       3       0
# 12         Joan     Crawford   25       2      5       1       0
# ...

# %%
input.shape
# Out:
# (59, 7)

# %%
input.head()
# Out:
#      Name      Surname  Age  Smokes  AreaQ  Alkhol  Result
# 0    John         Wick   35       3      5       4       1
# 1    John  Constantine   27      20      2       5       1
# 2  Camela     Anderson   30       0      5       2       0
# 3    Alex       Telles   28       0      8       1       0
# 4   Diego     Maradona   68       4      5       6       1

# %%
input.Age
# Out:
# 0     35
# 1     27
# 2     30
# 3     28
# 4     68
# 5     34
# 6     58
# 7     22
# 8     45
# 9     52
# 10    33
# 11    18
# 12    25
# 13    28
# 14    34
# 15    39
# 16    42
# 17    19
# 18    62
# 19    73
# 20    55
# 21    33
# 22    22
# 23    44
# 24    77
# 25    21
# 26    37
# 27    34
# 28    55
# 29    40
# 30    36
# 31    56
# 32    47
# 33    62
# 34    26
# 35    25
# 36    59
# 37    62
# 38    33
# 39    37
# 40    50
# 41    47
# 42    69
# 43    63
# 44    39
# 45    21
# 46    31
# 47    28
# 48    53
# 49    62
# 50    42
# 51    44
# 52    26
# 53    35
# 54    26
# 55    77
# 56    75
# 57    43
# 58    51
# Name: Age, dtype: int64

# %%
input['Smokes']
# Out:
# 0      3
# 1     20
# 2      0
# 3      0
# 4      4
# 5      0
# 6     15
# 7     12
# 8      2
# 9     18
# 10     4
# 11    10
# 12     2
# 13    20
# 14    25
# 15    18
# 16    22
# 17    12
# 18     5
# 19    10
# 20    15
# 21     8
# 22    20
# 23     5
# 24     3
# 25    20
# 26    15
# 27    12
# 28    20
# 29    20
# 30    13
# 31    20
# 32    15
# 33    25
# 34    10
# 35    20
# 36    20
# 37    15
# 38    25
# 39    10
# 40    20
# 41    12
# 42    20
# 43    20
# 44    15
# 45    20
# 46    20
# 47    10
# 48    20
# 49    20
# 50    12
# 51    30
# 52    34
# 53    20
# 54    13
# 55    20
# 56    15
# 57    30
# 58    25
# Name: Smokes, dtype: int64

# %%
input.iloc[0]
# Out:
# Name       John
# Surname    Wick
# Age          35
# Smokes        3
# AreaQ         5
# Alkhol        4
# Result        1
# Name: 0, dtype: object

# %%
input.iloc[:,0]
# Out:
# 0            John
# 1            John
# 2          Camela
# 3            Alex
# 4           Diego
# 5       Cristiano
# 6          Mihail
# 7           Kathy
# 8          Nicole
# 9             Ray
# 10        Fredric
# 11            Yul
# 12           Joan
# 13           Jane
# 14           Anna
# 15     Katharine
# 16     Katharine
# 17         Barbra
# 18        Maggie
# 19        Glenda
# 20          Jane
# 21    Maximilian
# 22       Gregory
# 23        Sidney
# 24           Rex
# 25           Lee
# 26          Paul
# 27           Rod
# 28          John
# 29          Gene
# 30        Marlon
# 31          Jack
# 32          Jack
# 33         Peter
# 34       Richard
# 35        Dustin
# 36         Henry
# 37        Robert
# 38         Ellen
# 39          Faye
# 40         Diane
# 41          Jane
# 42         Sally
# 43         Sissy
# 44       Jessica
# 45       Gwyneth
# 46         Halle
# 47        Nicole
# 48      Charlize
# 49     Katharine
# 50     Katharine
# ...

# %%
input.describe()
# Out:
#              Age     Smokes      AreaQ     Alkhol     Result
# count  59.000000  59.000000  59.000000  59.000000  59.000000
# mean   42.627119  15.067797   5.203390   3.237288   0.474576
# std    16.235230   7.984607   2.461984   2.380517   0.503640
# min    18.000000   0.000000   1.000000   0.000000   0.000000
# 25%    29.000000  10.000000   3.000000   1.000000   0.000000
# 50%    39.000000  15.000000   5.000000   3.000000   0.000000
# 75%    55.000000  20.000000   7.500000   5.000000   1.000000
# max    77.000000  34.000000  10.000000   8.000000   1.000000

# %%
input.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59 entries, 0 to 58
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Name     59 non-null     object
#  1   Surname  59 non-null     object
#  2   Age      59 non-null     int64
#  3   Smokes   59 non-null     int64
#  4   AreaQ    59 non-null     int64
#  5   Alkhol   59 non-null     int64
#  6   Result   59 non-null     int64
# dtypes: int64(5), object(2)
# memory usage: 3.4+ KB

# %%
#check isnull
input.isnull().sum()
# Out:
# Name       0
# Surname    0
# Age        0
# Smokes     0
# AreaQ      0
# Alkhol     0
# Result     0
# dtype: int64

# %%
input.Name.value_counts()
# Out:
# Name
# Katharine      4
# John           2
# Sidney         2
# Gregory        2
# Jane           2
# Glenda         2
# Maggie         2
# Jack           2
# Gwyneth        1
# Barbra         1
# Peter          1
# Richard        1
# Dustin         1
# Henry          1
# Alec           1
# Ernest         1
# Robert         1
# Charlize       1
# Jessica        1
# Nicole         1
# Ellen          1
# Halle          1
# Marlon         1
# Diane          1
# Sally          1
# Sissy          1
# Faye           1
# Paul           1
# Gene           1
# Yul            1
# Alex           1
# Diego          1
# Cristiano      1
# Mihail         1
# Kathy          1
# Nicole         1
# Ray            1
# Fredric        1
# Joan           1
# John           1
# Jane           1
# Anna           1
# Barbra         1
# Maximilian     1
# Rex            1
# Lee            1
# Camela         1
# Rod            1
# Charlton       1
# Name: count, dtype: int64

# %%
input.Name.unique()
# Out:
# array(['John', 'Camela', 'Alex', 'Diego', 'Cristiano', 'Mihail', 'Kathy',
#        'Nicole', 'Ray', 'Fredric', 'Yul', 'Joan', 'Jane', 'Anna',
#        'Katharine ', 'Barbra', 'Maggie ', 'Glenda ', 'Jane ',
#        'Maximilian ', 'Gregory ', 'Sidney ', 'Rex ', 'Lee ', 'Paul ',
#        'Rod ', 'John ', 'Gene ', 'Marlon ', 'Jack ', 'Peter ', 'Richard ',
#        'Dustin ', 'Henry ', 'Robert ', 'Ellen ', 'Faye ', 'Diane ',
#        'Sally ', 'Sissy ', 'Jessica ', 'Gwyneth ', 'Halle ', 'Nicole ',
#        'Charlize ', 'Barbra ', 'Ernest ', 'Alec ', 'Charlton '],
#       dtype=object)

# %%
import matplotlib.pyplot as plt
colors = ['blue', 'green']
print(plt.figure(figsize=(10, 8)))
hist = input.hist(bins=8)
# Out:
# Figure(1000x800)

# %%
import matplotlib.pyplot as plt
# Plot histograms for all columns in the DataFrame
plt.figure(figsize=(10, 6))
for column in input.columns:
    input['Age'].plot(kind='hist', bins=20, alpha=0.7, label=column)

plt.title('Histograms of All Columns')
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.tight_layout()
plt.show()

# %%
#box plot for specific attribute
hist = input['Smokes'].hist(bins=8)
plt.title('Histogram for Smoke Column')
plt.xlabel('No of Patients taken smoke')
plt.ylabel('Frequency')
plt.show()

# %%
#plot specific attribute
input.plot(y='Age', figsize=(9,6))
# Out:
# <Axes: >

# %%
#line plot for all attributes
axes = input.plot.line(subplots=True)
type(axes)
# Out:
# numpy.ndarray

# %%
ax = input.plot.line(subplots=True, color={"Age": "pink", "Smokes": "#742802","AreaQ": "green", "Alkhol": "yellow", "Result": "black"})

# %%
#Comparitive columns plot
lines = input.plot.line(x='Age', y='Smokes')
plt.title('Histogram for Smoke and Age Column')
plt.xlabel('Age of patients')
plt.ylabel('Smoke rate')
# Out:
# Text(0, 0.5, 'Smoke rate')

# %%
plot = input.plot.pie(y='Age', figsize=(8, 8))

# %%
ax2 = input.plot.scatter(x='Age', y='Smokes',c='AreaQ',colormap='magma')
